# %%
import xarray as xr
import matplotlib.pyplot as plt
import fpcluster as fc
import cartopy

# %%
lons,lats,height = fc.read_trajectories(['test_files/trajec_20190331_20190306.txt', 
                      'test_files/trajec_20190430_20190401.txt', 
                      'test_files/trajec_20190531_20190501.txt'])

# %%
ds = fc.cluster_trajectories(lons[1:,:],lats[1:,:],height, nclust=7)

# %%
ds.rmsclust
# Out:
# <xarray.DataArray 'rmsclust' (nclust: 7)>
# array([0.01587302, 0.0106383 , 0.00662252, 0.01041667, 0.00564972,
#        0.02439024, 0.01449275], dtype=float32)
# Coordinates:
#   * nclust   (nclust) int64 1 2 3 4 5 6 7
# Attributes:
#     long_name:  horizontal rms distance for each individual cluster
#     units:      m

# %%
fc.plot_trajectories(ds)
ax = plt.gca()
ax.set_extent([60,120,20,60])
ax.add_feature(cartopy.feature.BORDERS, linestyle=':')
ax.scatter(lons[0,0],  lats[0,0], marker='*', s=50, zorder=1200, color='black')
